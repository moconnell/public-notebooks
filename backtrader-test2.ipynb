# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

from enum import IntEnum, IntFlag
from math import ceil, floor
import backtrader as bt
import datetime as dt
import pandas as pd
import inspect
import math
import pdb

# %%
#%%pixie_debugger


def dump_args(func):
    '''Decorator to print function call details - parameters names and effective values.
    
    https://stackoverflow.com/questions/6200270/decorator-to-print-function-call-details-parameters-names-and-effective-values
    '''
    def wrapper(*args, **kwargs):
        func_args = inspect.signature(func).bind(*args, **kwargs).arguments
        func_args_str =  ', '.join('{} = {!r}'.format(*item) for item in func_args.items())
        print(f'{func.__module__}.{func.__qualname__} ( {func_args_str} )')
        return func(*args, **kwargs)
    return wrapper
        
        
class OrderObserver(bt.observer.Observer):
    lines = ('buy', 'sell')

    plotinfo = dict(plot=True, subplot=False, plotlinelabels=True)

    plotlines = dict(
        buy=dict(marker='*', markersize=4.0, color='lime', fillstyle='full'),
        sell=dict(marker='*', markersize=4.0, color='red')
    )

    def next(self):
        for order in self._owner._orderspending:
            if order.data not in self.datas:
                continue
                
            if order.status in [bt.Order.Accepted, bt.Order.Submitted] and order.exectype==bt.Order.StopLimit:
                if order.isbuy():
                    self.lines.buy[0] = order.created.price
                else:
                    self.lines.sell[0] = order.created.price

class CrossoverEvent(IntEnum):
    NONE = 0
    CROSS_UP = 1
    CROSS_DOWN = 2
    ABOVE = 3
    BELOW = 4
    
    
class Patterns(IntFlag):
    NONE = 0,
    Buy = 1,
    Sell = 2,
    Pattern1 = 4,
    Pattern2 = 8,
    Pattern3 = 16,
    Pattern4 = 32,
    Pattern5 = 64,
    Pattern6 = 128,
    Pattern7 = 256,
    Pattern8 = 512

    
class St(bt.Strategy):
    params = (
        ('semaperiod', 8),
        ('lemaperiod', 15),
        ('risk_percent', 1.0),  
        ('pip_size', 0.0001),  
        ('bar_size', dt.timedelta(minutes=240)),
        ('Filter1Enabled', True),
        ('Filter2Enabled', True),
        ('Filter3Enabled', True),
        ('Filter4Enabled', True),
        ('Filter5Enabled', True),
        ('Filter6Enabled', True),
        ('Filter7Enabled', True),
        ('Filter8Enabled', True)
    )
    
    def __init__(self):
        self.last_event = CrossoverEvent.NONE
        self.sema = bt.indicators.ExponentialMovingAverage(self.datas[0], period=self.params.semaperiod)
        self.lema = bt.indicators.ExponentialMovingAverage(self.datas[0], period=self.params.lemaperiod)
        self.open = self.datas[0].open
        self.high = self.datas[0].high
        self.low = self.datas[0].low
        self.close = self.datas[0].close
        self.trade_id = 1
        
    def logdata(self):
        txt = []
        txt.append('{}'.format(len(self)))
           
        txt.append('{}'.format(
            self.data.datetime.datetime(0).isoformat())
        )
        txt.append('{:.5f}'.format(self.data.open[0]))
        txt.append('{:.5f}'.format(self.data.high[0]))
        txt.append('{:.5f}'.format(self.data.low[0]))
        txt.append('{:.5f}'.format(self.data.close[0]))
        print(','.join(txt))
        
    def calc(self):
        time = self.data.datetime.datetime(0)
        shortEma = self.sema[0]
        longEma = self.lema[0]
        open_ = self.open[0]
        low = self.low[0]
        high = self.high[0]
        close = self.close[0]
        buyStrings = []
        sellStrings = []
        
        if shortEma > longEma:
            if self.last_event == CrossoverEvent.ABOVE:
                if high < longEma or high >= shortEma and low <= shortEma or high >= longEma and low <= longEma:
                    self.OnBuyStage3()
            elif self.last_event != CrossoverEvent.CROSS_UP:                    
                self.last_event = CrossoverEvent.CROSS_UP
                
        if shortEma < longEma:
            if self.last_event == CrossoverEvent.BELOW:
                if low > longEma or high >= shortEma and low <= shortEma or high >= longEma and low <= longEma:
                    self.OnSellStage3()
            elif self.last_event != CrossoverEvent.CROSS_DOWN:
                self.last_event = CrossoverEvent.CROSS_DOWN      
                
        if low > shortEma and self.last_event == CrossoverEvent.CROSS_UP:
            self.last_event = CrossoverEvent.ABOVE
        
        if high < shortEma and self.last_event == CrossoverEvent.CROSS_DOWN:
            self.last_event = CrossoverEvent.BELOW
        
    @dump_args
    def OnBuyStage3(self, index:int = 0):
        p = Patterns.NONE;

        if self.params.Filter1Enabled and self.IsLowerHigh(index) and self.IsLowerLow(index):
            p |= Patterns.Pattern1
        
        if self.params.Filter5Enabled and self.IsInsidePeriod(index):
            p |= Patterns.Pattern5
        
        if p != Patterns.NONE:
            self.log_output(index, p, Patterns.Buy)
            entry = self.round_up(self.high[index] + self.params.pip_size)
            limit = entry + self.params.pip_size
            isl = self.round_down(self.low[index] - self.params.pip_size)
            diff = limit - isl
            tp = limit + diff
            pips = diff / self.params.pip_size
            equity = self.broker.get_value()
            s = self.round_down(equity * self.params.risk_percent / 
                                (100 * pips * self.params.pip_size), 1000)
            # print('equity', equity, 'sell', s)
            entry_ord = self.buy(price=entry, plimit=limit, size=s, 
                                 exectype=bt.Order.StopLimit,
                                 # exectype=bt.Order.Limit,  
                                 valid=self.params.bar_size,
                                 tradeid=self.trade_id,
                                 transmit=False)
            isl_ord = self.sell(size=s, 
                                price=isl, 
                                exectype=bt.Order.StopTrail, # exectype=bt.Order.Stop, 
                                trailamount=diff,
                                parent=entry_ord,
                                tradeid=self.trade_id,
                                transmit=False)
            tp_ord = self.sell(size=s, 
                               price=tp, 
                               exectype=bt.Order.Limit, 
                               parent=entry_ord,
                               tradeid=self.trade_id,
                               transmit=True)
            self.trade_id += 1
        
    # @dump_args
    def OnSellStage3(self, index:int = 0):
        pass

    def round_down(self, value, rounding=None):
        rounding = rounding or self.params.pip_size
        return floor(value / rounding) * rounding
            
    def round_up(self, value, rounding=None):
        rounding = rounding or self.params.pip_size
        return ceil(value / rounding) * rounding            
            
    def log_output(self, index:int, p:Patterns, side:Patterns):
        matches = p | side
        time = self.data.datetime.datetime(0)
        open_ = self.open[0]
        low = self.low[0]
        high = self.high[0]
        close = self.close[0]
        print(f'{time}: ({open_:.5f}, {high:.5f}, {low:.5f}, {close:.5f}) {repr(matches)}')
            
    def IsHigherHigh(self, index:int = 0):
        return self.high[index] > self.high[index - 1]

    def IsLowerHigh(self, index:int = 0):      
        return self.high[index] < self.high[index - 1] 

    def IsLowerOrEqualHigh(self, index:int = 0):      
        return self.high[index] <= self.high[index - 1]         

    def IsHigherLow(self, index:int = 0):        
        return self.low[index] > self.low[index - 1]       

    def IsHigherOrEqualLow(self, index:int = 0):        
        return self.low[index] >= self.low[index - 1]

    def IsLowerLow(self, index:int = 0):        
        return self.low[index] < self.low[index - 1]

    def IsOutsidePeriod(self, index:int = 0):
        return self.IsLowerLow(index) and self.IsHigherHigh(index)        

    def IsInsidePeriod(self, index:int = 0):        
        return self.IsHigherOrEqualLow(index) and self.IsLowerOrEqualHigh(index)        

    def next(self):
        # self.logdata()
        self.calc()
        
    @dump_args
    def notify_order(self, order):
        # import pdb; pdb.set_trace()
        print(str(order))

    @dump_args
    def notify_trade(self, trade):
        pass
    
    # @dump_args
    def notify_cashvalue(self, cash, value):
        pass
    
    # @dump_args
    def notify_fund(self, cash, value, fundvalue, shares):
        pass
    
    def notify_store(self, msg, *args, **kwargs):
        pass
        
def run(args=None):
    datapath = 'data/EURUSD_M1_2010.h5'
    df = pd.read_hdf(datapath)
    data = bt.feeds.PandasData(dataname=df['2010-06-01':'2010-06-30']) 
    
    tf = bt.TimeFrame.Minutes  
    n = 240
    cerebro = bt.Cerebro(stdstats=False)
    cerebro.resampledata(data, timeframe=tf, compression=n)
    cerebro.addstrategy(St, bar_size=dt.timedelta(minutes=n))
    cerebro.addobserver(OrderObserver) 
    result = cerebro.run(stdstats=True)
    cerebro.plot(iplot=False, style='candle', volume=False, barupfill=False, barup='black', bardown='black')
    
if __name__ == '__main__':
    print("hello")
    run()
# Out:
# hello
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-11 16:00:00: (1.20760, 1.20970, 1.20550, 1.20930) <Patterns.Pattern5|Buy: 65>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11556ad30> )
# Ref: 1
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 22000
# Price: 1.2098
# Price Limit: 1.2099
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733934.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11556ada0> )
# Ref: 2
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -22000
# Price: 1.2054
# Price Limit: None
# TrailAmount: 0.0044999999999999485
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733934.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11556ae10> )
# Ref: 3
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -22000
# Price: 1.2144
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733934.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11556aeb8> )
# Ref: 1
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 22000
# Price: 1.2098
# Price Limit: 1.2099
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733934.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11556af60> )
# Ref: 2
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -22000
# Price: 1.2054
# Price Limit: None
# TrailAmount: 0.0044999999999999485
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733934.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11556afd0> )
# Ref: 3
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -22000
# Price: 1.2144
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733934.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-15 04:00:00: (1.22160, 1.22240, 1.21670, 1.21970) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557a278> )
# Ref: 4
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 16000
# Price: 1.2225000000000001
# Price Limit: 1.2226000000000001
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733938.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557a2e8> )
# Ref: 5
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -16000
# Price: 1.2165000000000001
# Price Limit: None
# TrailAmount: 0.006099999999999994
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733938.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557a358> )
# Ref: 6
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -16000
# Price: 1.2287000000000001
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733938.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557a438> )
# Ref: 4
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 16000
# Price: 1.2225000000000001
# Price Limit: 1.2226000000000001
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733938.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557a470> )
# Ref: 5
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -16000
# Price: 1.2165000000000001
# Price Limit: None
# TrailAmount: 0.006099999999999994
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733938.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557a4e0> )
# Ref: 6
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -16000
# Price: 1.2287000000000001
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733938.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-16 08:00:00: (1.22780, 1.23060, 1.22660, 1.22760) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557a7b8> )
# Ref: 7
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 22000
# Price: 1.2307000000000001
# Price Limit: 1.2308000000000001
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733939.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557a828> )
# Ref: 8
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -22000
# Price: 1.2264000000000002
# Price Limit: None
# TrailAmount: 0.0043999999999999595
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733939.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557a898> )
# Ref: 9
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -22000
# Price: 1.2352
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733939.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557a940> )
# Ref: 7
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 22000
# Price: 1.2307000000000001
# Price Limit: 1.2308000000000001
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733939.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557a9b0> )
# Ref: 8
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -22000
# Price: 1.2264000000000002
# Price Limit: None
# TrailAmount: 0.0043999999999999595
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733939.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557aa20> )
# Ref: 9
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -22000
# Price: 1.2352
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733939.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-17 00:00:00: (1.23020, 1.23020, 1.22590, 1.22680) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557acf8> )
# Ref: 10
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 21000
# Price: 1.2303
# Price Limit: 1.2304
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557ad68> )
# Ref: 11
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -21000
# Price: 1.2258
# Price Limit: None
# TrailAmount: 0.0045999999999999375
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557add8> )
# Ref: 12
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -21000
# Price: 1.2349999999999999
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557aeb8> )
# Ref: 10
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 21000
# Price: 1.2303
# Price Limit: 1.2304
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557aef0> )
# Ref: 11
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -21000
# Price: 1.2258
# Price Limit: None
# TrailAmount: 0.0045999999999999375
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557af60> )
# Ref: 12
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -21000
# Price: 1.2349999999999999
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-17 04:00:00: (1.22690, 1.22830, 1.22410, 1.22750) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557b2b0> )
# Ref: 13
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 22000
# Price: 1.2284000000000002
# Price Limit: 1.2285000000000001
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557b320> )
# Ref: 14
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -22000
# Price: 1.224
# Price Limit: None
# TrailAmount: 0.0045000000000001705
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557b390> )
# Ref: 15
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -22000
# Price: 1.2330000000000003
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557b470> )
# Ref: 13
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 22000
# Price: 1.2284000000000002
# Price Limit: 1.2285000000000001
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557b4a8> )
# Ref: 14
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -22000
# Price: 1.224
# Price Limit: None
# TrailAmount: 0.0045000000000001705
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557b4e0> )
# Ref: 15
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -22000
# Price: 1.2330000000000003
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733940.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-18 08:00:00: (1.23980, 1.24050, 1.23570, 1.23740) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557b7b8> )
# Ref: 16
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 19000
# Price: 1.2406000000000001
# Price Limit: 1.2407000000000001
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557b828> )
# Ref: 17
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -19000
# Price: 1.2356
# Price Limit: None
# TrailAmount: 0.0051000000000001044
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557b898> )
# Ref: 18
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -19000
# Price: 1.2458000000000002
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557b978> )
# Ref: 16
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 19000
# Price: 1.2406000000000001
# Price Limit: 1.2407000000000001
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557b9b0> )
# Ref: 17
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -19000
# Price: 1.2356
# Price Limit: None
# TrailAmount: 0.0051000000000001044
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557ba20> )
# Ref: 18
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -19000
# Price: 1.2458000000000002
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-18 12:00:00: (1.23730, 1.23930, 1.23520, 1.23640) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557bcf8> )
# Ref: 19
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 22000
# Price: 1.2394
# Price Limit: 1.2395
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557bd68> )
# Ref: 20
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -22000
# Price: 1.2351
# Price Limit: None
# TrailAmount: 0.0043999999999999595
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557bdd8> )
# Ref: 21
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -22000
# Price: 1.2439
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11557beb8> )
# Ref: 19
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 22000
# Price: 1.2394
# Price Limit: 1.2395
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557bef0> )
# Ref: 20
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -22000
# Price: 1.2351
# Price Limit: None
# TrailAmount: 0.0043999999999999595
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11557bf60> )
# Ref: 21
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -22000
# Price: 1.2439
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-18 16:00:00: (1.23650, 1.23730, 1.23560, 1.23720) <Patterns.Pattern5|Buy: 65>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558a2b0> )
# Ref: 22
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 49000
# Price: 1.2374
# Price Limit: 1.2375
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558a320> )
# Ref: 23
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -49000
# Price: 1.2355
# Price Limit: None
# TrailAmount: 0.0020000000000000018
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558a390> )
# Ref: 24
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -49000
# Price: 1.2395
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558a470> )
# Ref: 22
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 49000
# Price: 1.2374
# Price Limit: 1.2375
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558a4a8> )
# Ref: 23
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -49000
# Price: 1.2355
# Price Limit: None
# TrailAmount: 0.0020000000000000018
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558a4e0> )
# Ref: 24
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -49000
# Price: 1.2395
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733941.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-21 00:00:00: (1.24150, 1.24380, 1.23670, 1.24200) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558a7b8> )
# Ref: 25
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 13000
# Price: 1.2439
# Price Limit: 1.244
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558a828> )
# Ref: 26
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -13000
# Price: 1.2365000000000002
# Price Limit: None
# TrailAmount: 0.00749999999999984
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558a898> )
# Ref: 27
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -13000
# Price: 1.2514999999999998
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558a978> )
# Ref: 25
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 13000
# Price: 1.2439
# Price Limit: 1.244
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558a9b0> )
# Ref: 26
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -13000
# Price: 1.2365000000000002
# Price Limit: None
# TrailAmount: 0.00749999999999984
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558aa20> )
# Ref: 27
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -13000
# Price: 1.2514999999999998
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-21 08:00:00: (1.24280, 1.24300, 1.23780, 1.23920) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558acf8> )
# Ref: 28
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 18000
# Price: 1.2431
# Price Limit: 1.2432
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558ad68> )
# Ref: 29
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -18000
# Price: 1.2377
# Price Limit: None
# TrailAmount: 0.00550000000000006
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558add8> )
# Ref: 30
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -18000
# Price: 1.2487000000000001
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558aeb8> )
# Ref: 28
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 18000
# Price: 1.2431
# Price Limit: 1.2432
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558aef0> )
# Ref: 29
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -18000
# Price: 1.2377
# Price Limit: None
# TrailAmount: 0.00550000000000006
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558af60> )
# Ref: 30
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -18000
# Price: 1.2487000000000001
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-21 12:00:00: (1.23910, 1.23970, 1.23480, 1.23810) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x115592278> )
# Ref: 31
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 18000
# Price: 1.2398
# Price Limit: 1.2399
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x1155922e8> )
# Ref: 32
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -18000
# Price: 1.2346000000000001
# Price Limit: None
# TrailAmount: 0.00529999999999986
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x115592358> )
# Ref: 33
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -18000
# Price: 1.2451999999999999
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x115592400> )
# Ref: 31
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 18000
# Price: 1.2398
# Price Limit: 1.2399
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x115592470> )
# Ref: 32
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -18000
# Price: 1.2346000000000001
# Price Limit: None
# TrailAmount: 0.00529999999999986
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x1155924e0> )
# Ref: 33
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -18000
# Price: 1.2451999999999999
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-21 16:00:00: (1.23800, 1.23800, 1.23030, 1.23150) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x1155927b8> )
# Ref: 34
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 12000
# Price: 1.2381
# Price Limit: 1.2382
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x115592828> )
# Ref: 35
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -12000
# Price: 1.2301
# Price Limit: None
# TrailAmount: 0.008099999999999996
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x115592898> )
# Ref: 36
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -12000
# Price: 1.2463
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x115592978> )
# Ref: 34
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 12000
# Price: 1.2381
# Price Limit: 1.2382
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x1155929b0> )
# Ref: 35
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -12000
# Price: 1.2301
# Price Limit: None
# TrailAmount: 0.008099999999999996
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x115592a20> )
# Ref: 36
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -12000
# Price: 1.2463
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-21 20:00:00: (1.23160, 1.23270, 1.23050, 1.23230) <Patterns.Pattern5|Buy: 65>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x115592d30> )
# Ref: 37
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 38000
# Price: 1.2328000000000001
# Price Limit: 1.2329
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x115592da0> )
# Ref: 38
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -38000
# Price: 1.2303
# Price Limit: None
# TrailAmount: 0.0026000000000001577
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x115592e10> )
# Ref: 39
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -38000
# Price: 1.2355000000000003
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x115592ac8> )
# Ref: 37
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 38000
# Price: 1.2328000000000001
# Price Limit: 1.2329
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x115592f28> )
# Ref: 38
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -38000
# Price: 1.2303
# Price Limit: None
# TrailAmount: 0.0026000000000001577
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x115592f60> )
# Ref: 39
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -38000
# Price: 1.2355000000000003
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733944.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-25 00:00:00: (1.23340, 1.23360, 1.22960, 1.23210) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558d278> )
# Ref: 40
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 23000
# Price: 1.2337
# Price Limit: 1.2338
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558d2e8> )
# Ref: 41
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -23000
# Price: 1.2295
# Price Limit: None
# TrailAmount: 0.0042999999999999705
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558d358> )
# Ref: 42
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -23000
# Price: 1.2381
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558d438> )
# Ref: 40
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 23000
# Price: 1.2337
# Price Limit: 1.2338
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558d470> )
# Ref: 41
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -23000
# Price: 1.2295
# Price Limit: None
# TrailAmount: 0.0042999999999999705
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558d4e0> )
# Ref: 42
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -23000
# Price: 1.2381
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-25 08:00:00: (1.23310, 1.23380, 1.22530, 1.23090) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558d7b8> )
# Ref: 43
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 11000
# Price: 1.2339
# Price Limit: 1.234
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558d828> )
# Ref: 44
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -11000
# Price: 1.2252
# Price Limit: None
# TrailAmount: 0.008799999999999919
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558d898> )
# Ref: 45
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -11000
# Price: 1.2428
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558d978> )
# Ref: 43
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 11000
# Price: 1.2339
# Price Limit: 1.234
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558d9b0> )
# Ref: 44
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -11000
# Price: 1.2252
# Price Limit: None
# TrailAmount: 0.008799999999999919
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558da20> )
# Ref: 45
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -11000
# Price: 1.2428
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-25 12:00:00: (1.23100, 1.23360, 1.22790, 1.23300) <Patterns.Pattern5|Buy: 65>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558dcf8> )
# Ref: 46
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 16000
# Price: 1.2337
# Price Limit: 1.2338
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558dd68> )
# Ref: 47
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -16000
# Price: 1.2278
# Price Limit: None
# TrailAmount: 0.006000000000000005
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558ddd8> )
# Ref: 48
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -16000
# Price: 1.2398
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11558deb8> )
# Ref: 46
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 16000
# Price: 1.2337
# Price Limit: 1.2338
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558def0> )
# Ref: 47
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -16000
# Price: 1.2278
# Price Limit: None
# TrailAmount: 0.006000000000000005
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11558df60> )
# Ref: 48
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -16000
# Price: 1.2398
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733948.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-28 04:00:00: (1.23810, 1.23850, 1.23450, 1.23470) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11570d278> )
# Ref: 49
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 22000
# Price: 1.2386000000000001
# Price Limit: 1.2387000000000001
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570d2e8> )
# Ref: 50
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -22000
# Price: 1.2343
# Price Limit: None
# TrailAmount: 0.0044000000000001815
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570d358> )
# Ref: 51
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -22000
# Price: 1.2431000000000003
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11570d400> )
# Ref: 49
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 22000
# Price: 1.2386000000000001
# Price Limit: 1.2387000000000001
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570d470> )
# Ref: 50
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -22000
# Price: 1.2343
# Price Limit: None
# TrailAmount: 0.0044000000000001815
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570d4e0> )
# Ref: 51
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -22000
# Price: 1.2431000000000003
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-28 08:00:00: (1.23480, 1.23810, 1.23290, 1.23450) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11570d7b8> )
# Ref: 52
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 18000
# Price: 1.2382
# Price Limit: 1.2383
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570d828> )
# Ref: 53
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -18000
# Price: 1.2328000000000001
# Price Limit: None
# TrailAmount: 0.005499999999999838
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570d898> )
# Ref: 54
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -18000
# Price: 1.2437999999999998
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11570d908> )
# Ref: 52
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 18000
# Price: 1.2382
# Price Limit: 1.2383
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570d9b0> )
# Ref: 53
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -18000
# Price: 1.2328000000000001
# Price Limit: None
# TrailAmount: 0.005499999999999838
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570da58> )
# Ref: 54
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -18000
# Price: 1.2437999999999998
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.OnBuyStage3 ( self = <__main__.St object at 0x11555bb00> )
# 2010-06-28 12:00:00: (1.23440, 1.23480, 1.23090, 1.23160) <Patterns.Pattern1|Buy: 5>
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11570dd30> )
# Ref: 55
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 23000
# Price: 1.2349
# Price Limit: 1.235
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570dda0> )
# Ref: 56
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -23000
# Price: 1.2308000000000001
# Price Limit: None
# TrailAmount: 0.0041999999999999815
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570de10> )
# Ref: 57
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -23000
# Price: 1.2392
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.BuyOrder object at 0x11570def0> )
# Ref: 55
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 23000
# Price: 1.2349
# Price Limit: 1.235
# TrailAmount: None
# TrailPercent: None
# ExecType: 4
# ExecType: StopLimit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570df28> )
# Ref: 56
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -23000
# Price: 1.2308000000000001
# Price Limit: None
# TrailAmount: 0.0041999999999999815
# TrailPercent: None
# ExecType: 5
# ExecType: StopTrail
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# __main__.St.notify_order ( self = <__main__.St object at 0x11555bb00>, order = <backtrader.order.SellOrder object at 0x11570df60> )
# Ref: 57
# OrdType: 1
# OrdType: Sell
# Status: 8
# Status: Rejected
# Size: -23000
# Price: 1.2392
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 2
# ExecType: Limit
# CommInfo: None
# End of Session: 733951.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
